# %% [markdown]
# # Data Preprocessing

# %%
import pandas as pd

df = pd.read_csv("../data/amazon_data.csv")

categorical_columns = df.select_dtypes(include=["object"]).columns
numerical_columns = df.select_dtypes(include=["number"]).columns

# for col in categorical_columns:
#     df[col] = df[col].fillna(df[col].mode()[0])

for col in numerical_columns:
    df[col] = df[col].fillna(df[col].mean()).astype(int)

df.to_csv("cleaned_dataset.csv", index=False)

print("Data cleaning completed and saved as cleaned_dataset.csv")
# Out:
# Data cleaning completed and saved as cleaned_dataset.csv

# %% [markdown]
# # Image PreProcessing

# %%
import cv2
import os
import numpy as np

input_folder = "../data/product_images/"  
output_folder = "processed_images/"  
os.makedirs(output_folder, exist_ok=True)

IMG_SIZE = (224, 224)

for filename in os.listdir(input_folder):
    if filename.endswith(('.jpg', '.png', '.jpeg')):  
        img_path = os.path.join(input_folder, filename)
        img = cv2.imread(img_path)

        if img is None:
            print(f"Skipping {filename}: Unable to load image.")
            continue
        
        img_resized = cv2.resize(img, IMG_SIZE)

        save_path = os.path.join(output_folder, filename)
        cv2.imwrite(save_path, img_resized)  
        print(f"Processed: {filename}")

print("✅ Image preprocessing completed!")
# Out:
# Processed: product_1740573768_34.jpg
# Processed: product_1740573269_9.jpg
# Processed: product_1740574675_15.jpg
# Processed: product_1740574743_28.jpg
# Processed: product_1740573336_22.jpg
# Processed: product_1740573595_1.jpg
# Processed: product_1740573307_16.jpg
# Processed: product_1740573577_33.jpg
# Processed: product_1740574638_8.jpg
# Processed: product_1740573663_14.jpg
# Processed: product_1740573915_28.jpg
# Processed: product_1740573721_25.jpg
# Processed: product_1740573361_27.jpg
# Processed: product_1740574886_22.jpg
# Processed: product_1740573520_22.jpg
# Processed: product_1740573792_3.jpg
# Processed: product_1740574941_33.jpg
# Processed: product_1740573243_4.jpg
# Processed: product_1740574762_32.jpg
# Processed: product_1740573462_11.jpg
# Processed: product_1740574906_26.jpg
# Processed: product_1740573556_29.jpg
# Processed: product_1740573274_10.jpg
# Processed: product_1740573910_27.jpg
# Processed: product_1740574711_22.jpg
# Processed: product_1740574856_16.jpg
# Processed: product_1740573222_0.jpg
# Processed: product_1740573689_19.jpg
# Processed: product_1740573673_16.jpg
# Processed: product_1740573514_21.jpg
# Processed: product_1740573432_5.jpg
# Processed: product_1740573709_23.jpg
# Processed: product_1740573880_21.jpg
# Processed: product_1740573326_20.jpg
# Processed: product_1740573504_19.jpg
# Processed: product_1740573840_13.jpg
# Processed: product_1740573366_28.jpg
# Processed: product_1740573936_32.jpg
# Processed: product_1740573699_21.jpg
# Processed: product_1740573801_5.jpg
# Processed: product_1740574846_14.jpg
# Processed: product_1740573647_11.jpg
# Processed: product_1740573831_11.jpg
# Processed: product_1740574644_9.jpg
# Processed: product_1740573382_31.jpg
# Processed: product_1740574669_14.jpg
# Processed: product_1740573816_8.jpg
# Processed: product_1740574827_10.jpg
# Processed: product_1740573295_14.jpg
# Processed: product_1740574727_25.jpg
# Processed: product_1740573483_15.jpg
# Processed: product_1740573316_18.jpg
# Processed: product_1740573727_26.jpg
# Processed: product_1740574768_33.jpg
# Processed: product_1740573550_28.jpg
# Processed: product_1740573227_1.jpg
# Processed: product_1740574936_32.jpg
# Processed: product_1740573259_7.jpg
# Processed: product_1740573351_25.jpg
# Processed: product_1740574717_23.jpg
# Processed: product_1740574794_3.jpg
# Processed: product_1740573478_14.jpg
# Processed: product_1740573301_15.jpg
# Processed: product_1740573797_4.jpg
# Processed: product_1740574659_12.jpg
# Processed: product_1740573806_6.jpg
# Processed: product_1740573835_12.jpg
# Processed: product_1740573614_5.jpg
# Processed: product_1740574803_5.jpg
# Processed: product_1740574921_29.jpg
# Processed: product_1740574705_21.jpg
# Processed: product_1740573341_23.jpg
# Processed: product_1740574871_19.jpg
# Processed: product_1740573437_6.jpg
# Processed: product_1740573748_30.jpg
# Processed: product_1740574752_30.jpg
# Processed: product_1740574680_16.jpg
# Processed: product_1740573775_0.jpg
# Processed: product_1740574900_25.jpg
# Processed: product_1740573311_17.jpg
# Processed: product_1740574649_10.jpg
# Processed: product_1740574613_3.jpg
# Processed: product_1740573582_34.jpg
# Processed: product_1740574915_28.jpg
# Processed: product_1740573545_27.jpg
# Processed: product_1740573865_18.jpg
# Processed: product_1740573411_1.jpg
# Processed: product_1740574890_23.jpg
# Processed: product_1740573875_20.jpg
# Processed: product_1740574633_7.jpg
# Processed: product_1740573589_0.jpg
# Processed: product_1740573609_4.jpg
# Processed: product_1740574926_30.jpg
# Processed: product_1740573860_17.jpg
# Processed: product_1740573238_3.jpg
# Processed: product_1740573896_24.jpg
# Processed: product_1740573683_18.jpg
# Processed: product_1740573489_16.jpg
# Processed: product_1740574628_6.jpg
# Processed: product_1740573400_34.jpg
# Processed: product_1740573377_30.jpg
# Processed: product_1740574789_2.jpg
# Processed: product_1740573758_32.jpg
# Processed: product_1740574695_19.jpg
# Processed: product_1740573906_26.jpg
# Processed: product_1740573388_32.jpg
# Processed: product_1740573372_29.jpg
# Processed: product_1740573561_30.jpg
# Processed: product_1740573941_33.jpg
# Processed: product_1740573393_33.jpg
# Processed: product_1740574690_18.jpg
# Processed: product_1740573406_0.jpg
# Processed: product_1740573509_20.jpg
# Processed: product_1740573279_11.jpg
# Processed: product_1740574861_17.jpg
# Processed: product_1740573531_24.jpg
# Processed: product_1740574664_13.jpg
# Processed: product_1740573732_27.jpg
# Processed: product_1740574836_12.jpg
# Processed: product_1740573248_5.jpg
# Processed: product_1740573946_34.jpg
# Processed: product_1740573716_24.jpg
# Processed: product_1740574931_31.jpg
# Processed: product_1740573356_26.jpg
# Processed: product_1740574619_4.jpg
# Processed: product_1740574798_4.jpg
# Processed: product_1740574785_1.jpg
# Processed: product_1740574773_34.jpg
# Processed: product_1740573737_28.jpg
# Processed: product_1740573891_23.jpg
# Processed: product_1740573540_26.jpg
# Processed: product_1740574624_5.jpg
# Processed: product_1740573786_2.jpg
# Processed: product_1740573753_31.jpg
# Processed: product_1740574757_31.jpg
# Processed: product_1740573920_29.jpg
# Processed: product_1740574685_17.jpg
# Processed: product_1740573264_8.jpg
# Processed: product_1740574866_18.jpg
# Processed: product_1740573473_13.jpg
# Processed: product_1740574876_20.jpg
# Processed: product_1740573811_7.jpg
# Processed: product_1740573901_25.jpg
# Processed: product_1740574700_20.jpg
# Processed: product_1740573443_7.jpg
# Processed: product_1740573925_30.jpg
# Processed: product_1740573870_19.jpg
# Processed: product_1740573499_18.jpg
# Processed: product_1740573566_31.jpg
# Processed: product_1740574895_24.jpg
# Processed: product_1740573284_12.jpg
# Processed: product_1740573658_13.jpg
# Processed: product_1740573704_22.jpg
# Processed: product_1740573954_0.jpg
# Processed: product_1740574738_27.jpg
# Processed: product_1740573346_24.jpg
# Processed: product_1740574818_8.jpg
# Processed: product_1740573694_20.jpg
# Processed: product_1740573457_10.jpg
# Processed: product_1740573632_8.jpg
# Processed: product_1740574654_11.jpg
# Processed: product_1740573781_1.jpg
# Processed: product_1740573448_8.jpg
# Processed: product_1740573668_15.jpg
# Processed: product_1740574779_0.jpg
# Processed: product_1740574822_9.jpg
# Processed: product_1740574722_24.jpg
# Processed: product_1740573423_3.jpg
# Processed: product_1740573642_10.jpg
# Processed: product_1740574748_29.jpg
# Processed: product_1740574851_15.jpg
# Processed: product_1740574808_6.jpg
# Processed: product_1740574607_2.jpg
# Processed: product_1740573885_22.jpg
# Processed: product_1740573826_10.jpg
# Processed: product_1740573494_17.jpg
# Processed: product_1740574813_7.jpg
# Processed: product_1740573331_21.jpg
# Processed: product_1740573620_6.jpg
# Processed: product_1740573453_9.jpg
# Processed: product_1740573321_19.jpg
# Processed: product_1740573427_4.jpg
# Processed: product_1740573637_9.jpg
# Processed: product_1740574881_21.jpg
# Processed: product_1740573855_16.jpg
# Processed: product_1740574841_13.jpg
# Processed: product_1740573290_13.jpg
# Processed: product_1740573535_25.jpg
# Processed: product_1740573652_12.jpg
# Processed: product_1740573418_2.jpg
# Processed: product_1740573254_6.jpg
# Processed: product_1740573821_9.jpg
# Processed: product_1740573599_2.jpg
# Processed: product_1740574911_27.jpg
# Processed: product_1740573763_33.jpg
# Processed: product_1740574732_26.jpg
# Processed: product_1740573604_3.jpg
# Processed: product_1740573678_17.jpg
# Processed: product_1740574832_11.jpg
# Processed: product_1740573233_2.jpg
# Processed: product_1740573845_14.jpg
# Processed: product_1740573467_12.jpg
# Processed: product_1740573525_23.jpg
# Processed: product_1740573742_29.jpg
# Processed: product_1740573849_15.jpg
# Processed: product_1740573931_31.jpg
# Processed: product_1740573572_32.jpg
# Processed: product_1740574946_34.jpg
# Processed: product_1740573626_7.jpg
# ✅ Image preprocessing completed!
